# %%
import os
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import cv2 
import matplotlib.pyplot as plt

# %%
# defining root directory
from PIL import Image

root_dir = "../content/drive/MyDrive/AIoT_DS/final/images"

files =  os.path.join(root_dir)
File_names = os.listdir(files)
print("This is the list of all the files present in the path given to us:\n")
print(File_names)

# plot here
fig, axes = plt.subplots(2, 3, figsize=(15, 8))
first_five = File_names[0:6]

def subplots():
# Use the axes for plotting
    i = 0
    j = 0
    k = 0
    for k in range(5):
        state = os.path.join(root_dir, first_five[k])
        img = Image.open(state)
        axes[i,j].imshow(img)
        
        if k==2:
            i +=1
            j = 0
        else:
            j += 1


    plt.tight_layout(pad=2);
    
subplots()
# Out:
# This is the list of all the files present in the path given to us:
#
# ['accelgor.png', 'altaria.png', 'ambipom.png', 'absol.png', 'abomasnow.png', 'aggron.png', 'alomomola.png', 'aegislash-blade.png', 'abra.png', 'alakazam.png', 'aerodactyl.png', 'aipom.png', 'amaura.png', 'beldum.png', 'arceus.png', 'beautifly.png', 'baltoy.png', 'chespin.png', 'blacephalon.jpg', 'aromatisse.png', 'budew.png', 'anorith.png', 'blastoise.png', 'ampharos.png', 'chesnaught.png', 'bellsprout.png', 'buzzwole.jpg', 'charjabug.jpg', 'bidoof.png', 'chatot.png', 'clawitzer.png', 'carracosta.png', 'blissey.png', 'bastiodon.png', 'aron.png', 'bunnelby.png', 'bewear.jpg', 'chikorita.png', 'cinccino.png', 'bouffalant.png', 'chimchar.png', 'cacturne.png', 'ariados.png', 'combee.png', 'clauncher.png', 'cobalion.png', 'charmander.png', 'combusken.png', 'arbok.png', 'carnivine.png', 'chandelure.png', 'camerupt.png', 'avalugg.png', 'chimecho.png', 'clamperl.png', 'beedrill.png', 'celebi.png', 'butterfree.png', 'blitzle.png', 'clefairy.png', 'brionne.jpg', 'burmy.png', 'caterpie.png', 'chingling.png', 'boldore.png', 'araquanid.jpg', 'cascoon.png', 'chansey.png', 'cacnea.png', 'carvanha.png', 'barboach.png', 'braixen.png', 'bronzong.png', 'breloom.png', 'azumarill.png', 'barbaracle.png', 'azurill.png', 'basculin-red-striped.png', 'cherubi.png', 'arcanine.png', 'bayleef.png', 'aurorus.png', 'bibarel.png', 'articuno.png', 'archen.png', 'castform.png', 'blaziken.png', 'bellossom.png', 'audino.png', 'axew.png', 'clefable.png', 'bronzor.png', 'banette.png', 'carbink.png', 'chinchou.png', 'armaldo.png', 'amoonguss.png', 'buizel.png', 'buneary.png', 'braviary.png', 'bagon.png', 'cloyster.png', 'claydol.png', 'bruxish.jpg', 'azelf.png', 'bulbasaur.png', 'cofagrigus.png', 'celesteela.jpg', 'beartic.png', 'binacle.png', 'charizard.png', 'cleffa.png', 'bonsly.png', 'cherrim.png', 'charmeleon.png', 'bounsweet.jpg', 'bisharp.png', 'archeops.png', 'bergmite.png', 'beheeyem.png', 'doduo.png', 'flareon.png', 'drampa.jpg', 'cubchoo.png', 'drifloon.png', 'eevee.png', 'ferrothorn.png', 'delphox.png', 'dhelmise.jpg', 'dialga.png', 'deino.png', 'cryogonal.png', 'dewpider.jpg', 'espeon.png', 'exeggutor.png', 'crabrawler.jpg', 'elgyem.png', 'durant.png', 'donphan.png', 'fearow.png', 'dragalge.png', 'diggersby.png', 'electivire.png', 'florges.png', 'finneon.png', 'feebas.png', 'delcatty.png', 'dragonite.png', 'entei.png', 'comfey.jpg', 'dragonair.png', 'elekid.png', 'cresselia.png', 'cosmoem.jpg', 'drifblim.png', 'corphish.png', 'delibird.png', 'fomantis.jpg', 'druddigon.png', 'dwebble.png', 'dugtrio.png', 'dustox.png', 'drapion.png', 'diglett.png', 'drowzee.png', 'dewott.png', 'dusclops.png', 'foongus.png', 'cubone.png', 'dedenne.png', 'cradily.png', 'emboar.png', 'darumaka.png', 'emolga.png', 'cosmog.jpg', 'crobat.png', 'fennekin.png', 'diancie.png', 'farfetchd.png', 'darkrai.png', 'eelektrik.png', 'deerling.png', 'espurr.png', 'empoleon.png', 'crabominable.jpg', 'cyndaquil.png', 'doublade.png', 'duosion.png', 'electabuzz.png', 'corsola.png', 'ekans.png', 'darmanitan-standard.png', 'croagunk.png', 'flaaffy.png', 'flygon.png', 'dunsparce.png', 'decidueye.jpg', 'exeggcute.png', 'conkeldurr.png', 'fletchinder.png', 'dewgong.png', 'cutiefly.jpg', 'croconaw.png', 'electrike.png', 'drilbur.png', 'excadrill.png', 'eelektross.png', 'dartrix.jpg', 'dodrio.png', 'dusknoir.png', 'ferroseed.png', 'cottonee.png', 'crawdaunt.png', 'floatzel.png', 'electrode.png', 'ditto.png', 'crustle.png', 'feraligatr.png', 'flabebe.png', 'escavalier.png', 'duskull.png', 'exploud.png', 'floette.png', 'forretress.png', 'ducklett.png', 'fletchling.png', 'cranidos.png', 'deoxys-normal.png', 'dratini.png', 'geodude.png', 'heatmor.png', 'graveler.png', 'grubbin.jpg', 'golem.png', 'golett.png', 'grotle.png', 'gabite.png', 'frogadier.png', 'joltik.png', 'furfrou.png', 'furret.png', 'goomy.png', 'jolteon.png', 'heliolisk.png', 'hoopa-confined.png', 'gastrodon.png', 'gallade.png', 'jellicent.png', 'growlithe.png', 'hariyama.png', 'greninja.png', 'kadabra.png', 'houndour.png', 'hydreigon.png' ...

# %%
## Run the below cells as it is
data = pd.read_csv("../content/drive/MyDrive/AIoT_DS/final/pokemon.csv")
W=np.linalg.norm(data["Weight"])
data["Weight"]=data["Weight"]/np.linalg.norm(data["Weight"])
data.head()
# Out:
#          Name  Type1   Type2    Weight  Height
# 0   bulbasaur  Grass  Poison  0.001861     0.7
# 1     ivysaur  Grass  Poison  0.003507     1.0
# 2    venusaur  Grass  Poison  0.026975     2.0
# 3  charmander   Fire     NaN  0.002293     0.6
# 4  charmeleon   Fire     NaN  0.005125     1.1

# %%
import pandas as pd
import numpy as np
import os
import keras
import matplotlib.pyplot as plt
from keras.layers import Dense, GlobalAveragePooling2D, Dropout, Flatten
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.optimizers import Adam

# %%
## Run the below cells as it is
data_dict = {}

for key, val in zip(data["Name"], data["Weight"]):
    data_dict[key] = val
print(data_dict)
# Out:
# {'bulbasaur': 0.0018612529860869158, 'ivysaur': 0.0035067085245115803, 'venusaur': 0.026974680957781386, 'charmander': 0.002292847881411418, 'charmeleon': 0.005125189381978463, 'charizard': 0.024412086266792154, 'squirtle': 0.0024277212862003246, 'wartortle': 0.0060693032155008115, 'blastoise': 0.023063352218903085, 'caterpie': 0.0007822657477756602, 'metapod': 0.0026704934148203572, 'butterfree': 0.008631897906490044, 'weedle': 0.0008631897906490044, 'kakuna': 0.0026974680957781386, 'beedrill': 0.00795753088254551, 'pidgey': 0.00048554425724006494, 'pidgeotto': 0.008092404287334416, 'pidgeot': 0.010654998978323648, 'rattata': 0.0009441138335223485, 'raticate': 0.004990315977189556, 'spearow': 0.0005394936191556277, 'fearow': 0.010250378763956926, 'ekans': 0.0018612529860869158, 'arbok': 0.0175335426225579, 'pikachu': 0.0016184808574668831, 'raichu': 0.008092404287334416, 'sandshrew': 0.0032369617149337663, 'sandslash': 0.00795753088254551, 'nidoran-f': 0.001888227667044697, 'nidorina': 0.005394936191556277, 'nidoqueen': 0.016184808574668832, 'nidoran-m': 0.0024277212862003246, 'nidorino': 0.00526006278676737, 'nidoking': 0.01672430219382446, 'clefairy': 0.002023101071833604, 'clefable': 0.010789872383112555, 'vulpix': 0.0026704934148203572, 'ninetales': 0.005367961510598496, 'jigglypuff': 0.0014836074526779763, 'wigglytuff': 0.0032369617149337663, 'zubat': 0.002023101071833604, 'golbat': 0.014836074526779762, 'oddish': 0.001456632771720195, 'gloom': 0.002319822562369199, 'vileplume': 0.0050172906581473385, 'paras': 0.001456632771720195, 'parasect': 0.00795753088254551, 'venonat': 0.008092404287334416, 'venomoth': 0.0033718351197226733, 'diglett': 0.0002157974476622511, 'dugtrio': 0.008982568758941201, 'meowth': 0.0011329366002268183, 'persian': 0.008631897906490044, 'psyduck': 0.0052870374677251525, 'golduck': 0.02066260561366054, 'mankey': 0.007552910668178788, 'primeape': 0.008631897906490044, 'growlithe': 0.005125189381978463, 'arcanine': 0.041810755484561146, 'poliwag': 0.003344860438764892, 'poliwhirl': 0.005394936191556277, 'poliwrath': 0.01456632771720195, 'abra': 0.00526006278676737, 'kadabra': 0.015240694741146484, 'alakazam': 0.012947846859735065, 'machop': 0.00526006278676737, 'machoke': 0.019017150075235877, 'machamp': 0.0350670852451158, 'bellsprout': 0.0010789872383112555, 'weepinbell': 0.0017263795812980088, 'victreebel': 0.004181075548456115, 'tentacool': 0.012273479835790531, 'tentacruel': 0.014836074526779762, 'geodude': 0.005394936191556277, 'graveler': 0.028323415005670455, 'golem': 0.08092404287334416, 'ponyta': 0.008092404287334416, 'rapidash': 0.025625946909892318, 'slowpoke': 0.009710885144801298, 'slowbro': 0.02117512455185839, 'magnemite': 0.0016184808574668831, 'magneton': 0.016184808574668832, 'farfetchd': 0.004046202143667208, 'doduo': 0.010574074935450305, 'dodrio': 0.022982428176029742, 'seel': 0.024277212862003246, 'dewgong': 0.032369617149337664, 'grimer': 0.008092404287334416, 'muk': 0.008092404287334416, 'shellder': 0.0010789872383112555, 'cloyster': 0.035741452269060336, 'gastly': 2.6974680957781387e-05, 'haunter': 2.6974680957781387e-05, 'gengar': 0.01092474578790146, 'onix': 0.05664683001134091, 'drowzee': 0.00873979663032117, 'hypno': 0.020392858804082727, 'krabby': 0.0017533542622557902, 'kingler': 0.016184808574668832, 'voltorb': 0.0028053668196092642, 'electrode': 0.017965137517882403, 'exeggcute': 0.0006743670239445347, 'exeggutor': 0.032369617149337664, 'cubone': 0.0017533542622557902, 'marowak': 0.012138606431001623, 'hitmonlee': 0.01343339111697513, 'hitmonchan': 0.013541289840806256, 'lickitung': 0.017668416027346808, 'koffing': 0.0002697468095778139, 'weezing': 0.0025625946909892316, 'rhyhorn': 0.031020883101448595, 'rhydon': 0.032369617149337664, 'chansey': 0.00933323961139236, 'tangela': 0.009441138335223484, 'kangaskhan': 0.02157974476622511, 'horsea': 0.002157974476622511, 'seadra': 0.006743670239445347, 'goldeen': 0.004046202143667208, 'seaking': 0.01052012557353474, 'stary ...

# %%
final_images = []
final_labels = []
count = 0
files =  os.path.join(root_dir)
for file in File_names:
    count += 1
    img = cv2.imread(os.path.join(root_dir, file), cv2.COLOR_BGR2GRAY) 
    label = [data_dict[file.split(".")[0]]] 
    # append img in final_images list
    final_images.append(np.array(img))
    # append label in final_labels list
    final_labels.append(np.array(label))

print(final_labels)
# converting lists into numpy arrayn
# normalizing and reshaping the data 
final_images = np.array(final_images, dtype = np.float32)/255.0
final_labels = np.array(final_labels, dtype = np.int8).reshape(809, 1)
# Out:
# [array([0.00682459]), array([0.00555678]), array([0.00547586]), array([0.0126781]), array([0.03655069]), array([0.09710885]), array([0.008524]), array([0.01429658]), array([0.00526006]), array([0.01294785]), array([0.01591506]), array([0.00310209]), array([0.00679762]), array([0.0256799]), array([0.08631898]), array([0.00766081]), array([0.00579956]), array([0.00242772]), array([0.00350671]), array([0.00418108]), array([0.0003237]), array([0.00337184]), array([0.02306335]), array([0.01658943]), array([0.02427721]), array([0.00107899]), array([0.08998754]), array([0.00283234]), array([0.00539494]), array([0.00051252]), array([0.00952206]), array([0.02184949]), array([0.01262415]), array([0.04032715]), array([0.01618481]), array([0.00134873]), array([0.03641582]), array([0.00172638]), array([0.0020231]), array([0.02551805]), array([0.00167243]), array([0.0208784]), array([0.00903652]), array([0.00148361]), array([0.0022389]), array([0.0674367]), array([0.00229285]), array([0.00526006]), array([0.01753354]), array([0.00728316]), array([0.00925232]), array([0.0593443]), array([0.13622214]), array([0.00026975]), array([0.01416171]), array([0.00795753]), array([0.00134873]), array([0.0086319]), array([0.00803845]), array([0.0020231]), array([0.00472057]), array([0.00091714]), array([0.00078227]), array([0.00016185]), array([0.02751417]), array([0.02211924]), array([0.00310209]), array([0.00933324]), array([0.01383801]), array([0.00561073]), array([0.00051252]), array([0.00391133]), array([0.05044265]), array([0.01057407]), array([0.00768778]), array([0.02589569]), array([0.00053949]), array([0.00485544]), array([0.00089016]), array([0.04181076]), array([0.004262]), array([0.06069303]), array([0.00849702]), array([0.01494397]), array([0.00256259]), array([0.0002158]), array([0.01402683]), array([0.00156453]), array([0.00836215]), array([0.00485544]), array([0.01078987]), array([0.01631968]), array([0.00337184]), array([0.00153756]), array([0.00323696]), array([0.01839673]), array([0.00283234]), array([0.00795753]), array([0.00148361]), array([0.01105962]), array([0.01135634]), array([0.03574145]), array([0.02913266]), array([0.00512519]), array([8.09240429e-05]), array([0.00186125]), array([0.02063563]), array([0.26971983]), array([0.07013417]), array([0.00836215]), array([0.02441209]), array([0.00080924]), array([0.0040462]), array([0.00250865]), array([0.00512519]), array([0.00086319]), array([0.01888228]), array([0.0086319]), array([0.02683981]), array([0.00930626]), array([0.01057407]), array([0.00674367]), array([0.04990316]), array([0.00229285]), array([0.0003237]), array([0.00175335]), array([0.02967215]), array([0.01052013]), array([0.05664683]), array([0.18423707]), array([0.00466662]), array([0.03992253]), array([0.00107899]), array([0.00714829]), array([0.03236962]), array([0.00188823]), array([0.00242772]), array([0.00890164]), array([0.03236962]), array([0.01025038]), array([0.02198436]), array([0.01143726]), array([0.03738691]), array([0.00269747]), array([0.00188823]), array([0.00199613]), array([0.00879375]), array([0.05664683]), array([0.05340987]), array([8.09240429e-05]), array([0.00445082]), array([0.00633905]), array([0.02309033]), array([0.26971983]), array([0.0040462]), array([0.00310209]), array([0.00431595]), array([0.00040462]), array([0.03749481]), array([0.00391133]), array([0.00898257]), array([0.008524]), array([0.01658943]), array([0.0002158]), array([0.0087398]), array([0.0066088]), array([0.00825425]), array([0.00026975]), array([0.00175335]), array([0.00059344]), array([0.01629271]), array([0.04046202]), array([0.01011551]), array([0.00134873]), array([2.6974681e-05]), array([0.02023101]), array([0.00253562]), array([0.00237377]), array([0.0040462]), array([0.01362221]), array([0.00593443]), array([0.00526006]), array([0.00094411]), array([0.02279361]), array([0.04855443]), array([0.002131]), array([0.00121386]), array([0.00215797]), array([0.0080924]), array([0.00134873]), array([0.00186125]), array ...

# %%
from keras.models import Sequential
def create_model(input_shape):
    
    """
    It defines the model
    """
    # we will use ResNet50 architecture, with freezing top layers
    backbone = ResNet50(input_shape=input_shape, weights='imagenet', include_top=False)
    model = Sequential()
    model.add(backbone)
    
    #now we will add our custom layers
    #without drop layer, neural networks can easily overfit
    model.add(Dropout(0.2))
    model.add(GlobalAveragePooling2D())
    
    #final layer, since we are doing regression we will add only one neuron (unit)
    model.add(Dense(1, activation='linear'))
    optimizer = Adam(lr=0.0001)
    model.compile(optimizer=optimizer, loss='mae', metrics=['accuracy'])
    print(model.summary())

    return model

# %%
model = create_model(input_shape = (120, 120, 3))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 4, 4, 2048)        23587712
#
#  dropout_1 (Dropout)         (None, 4, 4, 2048)        0
#
#  global_average_pooling2d_1   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 23,589,761
# Trainable params: 23,536,641
# Non-trainable params: 53,120
# _________________________________________________________________
# None
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
# compile model (Use: Adam optimizer, categorical_crossentropy loss and metrics as Accuracy)
#model.compile(loss="mse", optimizer="adam",metrics=['accuracy'])

# fit model (use images and labels)
history = model.fit(final_images, final_labels, epochs=20)
# Out:
# Epoch 1/20
# 26/26 [==============================] - 8s 114ms/step - loss: 0.6714 - accuracy: 0.7528
# Epoch 2/20
# 26/26 [==============================] - 3s 115ms/step - loss: 0.7424 - accuracy: 0.7417
# Epoch 3/20
# 26/26 [==============================] - 3s 116ms/step - loss: 0.2287 - accuracy: 0.9493
# Epoch 4/20
# 26/26 [==============================] - 3s 116ms/step - loss: 0.1699 - accuracy: 0.9654
# Epoch 5/20
# 26/26 [==============================] - 3s 116ms/step - loss: 0.1419 - accuracy: 0.9703
# Epoch 6/20
# 26/26 [==============================] - 3s 116ms/step - loss: 0.1276 - accuracy: 0.9617
# Epoch 7/20
# 26/26 [==============================] - 3s 116ms/step - loss: 0.0850 - accuracy: 0.9778
# Epoch 8/20
# 26/26 [==============================] - 3s 117ms/step - loss: 0.1080 - accuracy: 0.9654
# Epoch 9/20
# 26/26 [==============================] - 3s 118ms/step - loss: 0.1137 - accuracy: 0.9728
# Epoch 10/20
# 26/26 [==============================] - 3s 118ms/step - loss: 0.0726 - accuracy: 0.9728
# Epoch 11/20
# 26/26 [==============================] - 3s 119ms/step - loss: 0.0713 - accuracy: 0.9703
# Epoch 12/20
# 26/26 [==============================] - 3s 119ms/step - loss: 0.0752 - accuracy: 0.9790
# Epoch 13/20
# 26/26 [==============================] - 3s 125ms/step - loss: 0.0722 - accuracy: 0.9889
# Epoch 14/20
# 26/26 [==============================] - 3s 121ms/step - loss: 0.0731 - accuracy: 0.9740
# Epoch 15/20
# 26/26 [==============================] - 3s 119ms/step - loss: 0.0616 - accuracy: 0.9790
# Epoch 16/20
# 26/26 [==============================] - 3s 119ms/step - loss: 0.0468 - accuracy: 0.9852
# Epoch 17/20
# 26/26 [==============================] - 3s 125ms/step - loss: 0.0666 - accuracy: 0.9691
# Epoch 18/20
# 26/26 [==============================] - 3s 120ms/step - loss: 0.0548 - accuracy: 0.9765
# Epoch 19/20
# 26/26 [==============================] - 3s 120ms/step - loss: 0.0458 - accuracy: 0.9864
# Epoch 20/20
# 26/26 [==============================] - 3s 120ms/step - loss: 0.0496 - accuracy: 0.9765

# %%
model.save("model_weight.h5")

# %%
# !mv "/content/model_weight.h5" "../content/drive/MyDrive/AIoT_DS/final/model_weight.h5"

# %%
#去背
from rembg import remove

#待处理的图片路径
input_path = 'out-1.png'
#处理后存储的图片路径
output_path = 'output1.png'

with open(input_path, 'rb') as i:
    with open(output_path, 'wb') as o:
        input = i.read()
        output = remove(input)
        o.write(output)

# %%
test_img =[]
test = cv2.imread("output1.png")
test = cv2.resize(test,(120,120))
test_img.append(np.array(test))
test_img = np.array(test_img, dtype = np.float32)/255.0

predictions = model.predict(test_img)
print(abs(predictions*W))
# Out:
# 1/1 [==============================] - 0s 20ms/step
# [[37.947323]]

# %%
#顯示圖片
from google.colab.patches import cv2_imshow
cv2_imshow(test)
# Out:
# <PIL.Image.Image image mode=RGB size=120x120 at 0x7FAB9503B970>
